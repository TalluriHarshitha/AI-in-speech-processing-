# %% [markdown]
# **AI in Speech Processing**
# **Lab-1**
# 01-02-2024

# %% [markdown]
# T. VNL Harshitha
# BL.EN.U4AIE21128

# %%
import librosa
import IPython.display as ipd

# %%
filename="C:\\Users\\HP\\Downloads\\Audio.wav"
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, sr = librosa.load(filename) 
librosa.display.waveshow(y)

# %% [markdown]
# Segment

# %%
filename="C:\\Users\\HP\\Downloads\\Audio.wav"
y, sr = librosa.load(filename, offset=1.25, duration=1.75)
print('y:',y)
print('sr:',sr)
# Out:
# y: [-0.02788534 -0.0486454  -0.04851469 ... -0.00049903 -0.00038906
#  -0.00013709]
# sr: 22050

# %%
from IPython.display import Audio, display
a=Audio(y, rate=sr)
display(a)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Segment 2

# %%
filename="C:\\Users\\HP\\Downloads\\Audio.wav"
y2, sr2 = librosa.load(filename, offset=0.3, duration=1.5)
print('y:',y2)
print('sr:',sr2)

b= Audio(y2, rate=sr2)
display(b)
# Out:
# y: [ 0.00012647  0.00014724  0.0001147  ...  0.00665893 -0.00419363
#   0.00282971]
# sr: 22050
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
